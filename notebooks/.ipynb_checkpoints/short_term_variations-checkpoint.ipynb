# %% [markdown]
# # Short term variations

# %% [markdown]
# ## Introduction
#
# I present here some preliminary results aimed at finding short time scale absorption line variations (~ minutes) likely caused by fast moving excomets close to the star (a few stellar radii). I have chosen to look at the far-UV SiIV doublet at 1394 and 1403 Å, because the exocometary variatons are evident, and the S/N is high for these lines, compared to other lines in the spectra. My hypothesis is that the emission originates from exocomets close to the star where the conditions for highly ionising Si are met.

# %% [markdown]
# ## Aim
# The aim is to look for short term variations. For this, I look at data taken during a single visit. In order to become sensitive to variations on the order of tens of minutes I have to divide the data into datasets of shorter exposuretimes. Fortunately this data is already available from the pipeline in fhe form of sumN.fits files, where N is an integer. I have been working with the \*sum[1..4].fits files where the average(*sum1.fits, *sum2.fits, *sum3.fits, *sum4.fits) = *sum.fits. This has the advantage that we have 4 times the number of spectra for a given visit at the cost of ~1/4 the exposure time.

# %% [markdown]
# ### Import the standard routines

# %%
import numpy as np
import json, sys, os

import matplotlib.pyplot as plt
from matplotlib import rc, cm

# get the path of the current directory
path = os.getcwd()
home = os.path.dirname(path)

# Print repository home directory
print("Repository home directory:",home)

# adding the src folder to the system path
sys.path.append(home+'/src')

from calculations import Calc

# We shorten the function name to make it easier to call the required a functions
c   = Calc()
# Out:
# Repository home directory: /home/pas/science/exocomets

# %% [markdown]
# ### We now import the parameters used for the analysis

# %%
# Importing parameters
with open(home+'/params.json') as param_file:    
   param = json.load(param_file)

# %%
# We read in the data directories we are using.
datadirs = param["datadirs"]

# We select part A which is the red end of the spectrum
part     = param["BetaPictoris"]["part"]

# %% [markdown]
# ### Get the data ans save them as a npz file

# %%
D = []

print("Data used for this analysis:")

for i in sorted(datadirs):
    print("\n",datadirs[i])
    D.append(c.GetData(param, home+'/'+datadirs[i]))


    
# We save the data
np.savez(home+'/data/D_'+part+'.npz', D, dtype=object)
# Out:
# Data used for this analysis:
#
#  data/2017-08-04/
# 	AVM shift: 0.0" 	EXP: 526s, 	Date: 2017-08-04, Time: 14:31:03 UTC
# 	AVM shift: 0.0" 	EXP: 526s, 	Date: 2017-08-04, Time: 14:43:00 UTC
# 	AVM shift: 0.0" 	EXP: 526s, 	Date: 2017-08-04, Time: 14:54:57 UTC
# 	AVM shift: 0.0" 	EXP: 526s, 	Date: 2017-08-04, Time: 15:06:54 UTC
# 	AVM shift: -1.1" 	EXP: 664s, 	Date: 2017-08-04, Time: 15:57:36 UTC
# 	AVM shift: -1.1" 	EXP: 664s, 	Date: 2017-08-04, Time: 16:11:13 UTC
# 	AVM shift: -1.1" 	EXP: 664s, 	Date: 2017-08-04, Time: 16:24:50 UTC
# 	AVM shift: -1.1" 	EXP: 664s, 	Date: 2017-08-04, Time: 16:38:27 UTC
# 	AVM shift: 1.1" 	EXP: 664s, 	Date: 2017-08-04, Time: 17:32:52 UTC
# 	AVM shift: 1.1" 	EXP: 664s, 	Date: 2017-08-04, Time: 17:46:29 UTC
# 	AVM shift: 1.1" 	EXP: 664s, 	Date: 2017-08-04, Time: 18:00:06 UTC
#
#  data/2017-10-21/
# 	AVM shift: 0.0" 	EXP: 444s, 	Date: 2017-10-20, Time: 17:09:09 UTC
# 	AVM shift: 0.0" 	EXP: 444s, 	Date: 2017-10-20, Time: 16:59:03 UTC
# ...

# %% [markdown]
# ### We now normalise and shift the data

# %% [markdown]
# Compare the polyfit parts around line 196 and compare it to the

# %%
D = c.LoadData(home+'/data/D_'+part+'.npz')
Dn = c.NormSpec(param, D)
Dns = c.ShiftSpec(param, Dn)
Dnsn = c.NormSpec(param, Dns)

# We save the data
np.savez(home+'/data/Dnsn_'+part+'.npz', Dns, dtype=object)
# Out:
# Normalising the spectra relative to first spectrum...
# Done
#
#
#
# Shifting the 1st observation:
#
#
# Observations done at: 2017-08-04 14:31:03
# ______________________________________________
#
#  Pixel shift [pix]:	 0
#  W shift [A]:		 0.0
#  RV shift [km/s]:	 0
# ______________________________________________
#
#
# Observations done at: 2017-08-04 14:43:00
# ______________________________________________
#
#  Pixel shift [pix]:	 2
#  W shift [A]:		 0.02
#  RV shift [km/s]:	 4
# ______________________________________________
#
#
# Observations done at: 2017-08-04 14:54:57
# ______________________________________________
#
#  Pixel shift [pix]:	 5
#  W shift [A]:		 0.05
#  RV shift [km/s]:	 11
# ______________________________________________
#
#
# Observations done at: 2017-08-04 15:06:54
# ______________________________________________
#
#  Pixel shift [pix]:	 -3
#  W shift [A]:		 -0.03
#  RV shift [km/s]:	 -6
# ______________________________________________
#
#
# ...

# %% [markdown]
# ### Load the data into a matrix of arrays

# %%
DP   = c.LoadData(home+'/data/Dnsn_'+part+'.npz')

# %% [markdown]
# Let's have a look at when the spectra were obtained

# %% [markdown]
# ## Inspecting the data

# %%
plotting_params = {'backend': 'wxAgg',
                   'font.family': 'serif',
                   'font.size': 22,
                   'lines.markersize' : 2,
                   'axes.labelsize': 22,
                   'legend.fontsize': 22,
                   'xtick.labelsize': 22,
                   'ytick.labelsize': 22,
                   'text.usetex': True}

plt.rcParams.update(plotting_params)


bin_size = 5 # Only for visualisation. Never used for calculation.

cool=cm.plasma(np.linspace(0.0,0.9,len(DP[0]))) # Create some nice colours for the plot

print('Looking at observations done on:')

for nobs in range(len(DP)):
    
    date = str(D[nobs][0][3])[:10]
    
    fig = plt.figure(figsize=(16.0,22.0))

    print('\n',date)
    
    ax1 = plt.subplot(121)
    Line1 = 1393.7550 # The first SiIV line
    rv = c.Wave2RV(DP[nobs][0][0],Line1,20.5) # Convert to RV space
    x, y = c.BinXY(rv,DP[nobs][0][1],bin_size) # Bin the data

    # Selecting a region for determening the baseline, e.g. flux = 0.
    n1 = 400  # km/s
    n2 = 1500 # km/s
    s1, s2 = c.RegionSelect(x, n1, n2)

    # Plot the vertical line at v = 0 km/s
    plt.plot([0,0],[-3.0e-12,0.5e-12],'--k',lw=0.5)

    # Plot the vertical line at v = -270 km/s (approx location of CO line)
    #plt.plot([-270,-270],[-3.0e-12,0.5e-12],'--k',lw=0.5)

    ticks = []
    times = []

    # In this plot we want to compare each observation to the first one:
    x1, y1 = c.BinXY(rv,DP[nobs][0][1],bin_size)

    for i in range(len(DP[0])):
        offset = i*3e-13
        x, y = c.BinXY(rv,DP[nobs][i][1],bin_size)

        ticks.append(np.median(y[s1:s2])-offset)
        times.append(str(DP[nobs][i][3])[11:])

        plt.step(x1,y1-offset,color="black",label=str(DP[nobs][i][3])[11:])
        plt.fill_between(x1,y1-i*3e-13,np.median(y1[s1:s2])*np.ones(len(x1))-offset,step='pre',color=cool[0],alpha=0.5)
        plt.step(x,y-offset,color="black",label=str(DP[nobs][i][3])[11:])
        plt.fill_between(x,y-i*3e-13,np.median(y[s1:s2])*np.ones(len(x))-offset,step='pre',color=cool[i],alpha=0.5)

    plt.xlabel(r'Radial Velocity [km/s]')
    plt.xlim(-400,700)
    plt.ylim(-2.95e-12,0.5e-12)
    #plt.sca(ax)
    #plt.gca().set_yticks(ticks) 
    #plt.gca().set_yticklabels(times)


    ax2 = plt.subplot(122)

    Line2 = 1402.7700
    rv = c.Wave2RV(DP[nobs][0][0],Line2,20.5)
    x, y = c.BinXY(rv,DP[nobs][0][1],bin_size)

    n1 = 400
    n2 = 1500
    s1, s2 = c.RegionSelect(x, n1, n2)

    plt.plot([0,0],[-3.0e-12,0.5e-12],'--k',lw=0.5)

    x1, y1 = c.BinXY(rv,DP[nobs][0][1],bin_size)

    for i in range(len(DP[nobs])):
        offset = i*3e-13
        x, y = c.BinXY(rv,DP[nobs][i][1],bin_size)

        ticks.append(np.median(y[s1:s2])-offset)
        times.append(str(DP[nobs][i][3])[11:])

        plt.step(x1,y1-offset,color="black",label=str(DP[nobs][i][3])[11:])
        plt.fill_between(x1,y1-i*3e-13,np.median(y1[s1:s2])*np.ones(len(x1))-offset,step='pre',color=cool[0],alpha=0.5)
        plt.step(x,y-offset,color="black",label=str(DP[nobs][i][3])[11:])
        plt.fill_between(x,y-i*3e-13,np.median(y[s1:s2])*np.ones(len(x))-offset,step='pre',color=cool[i],alpha=0.5)

    plt.xlabel(r'Radial Velocity [km/s]')

    ax2.set(yticklabels=[]) 
    ax2.set(ylabel=None)     

    plt.xlabel(r'Radial Velocity [km/s]')
    plt.xlim(-400,700)
    plt.ylim(-2.95e-12,0.5e-12)
    ax1.title.set_text('SiIV @ '+str(Line1)+' \AA')
    ax2.title.set_text('SiIV @ '+str(Line2)+' \AA')
    fig.tight_layout()
    plt.savefig(home+'/plots/'+date+'.pdf', bbox_inches='tight', pad_inches=0.1,dpi=300)
# Out:
# Looking at observations done on:
#
#  2017-08-04
#
#  2017-10-20

# %%
from scipy.optimize import curve_fit

def gauss(x,a,x0,sigma):
    return -a*np.exp(-(x-x0)**2/(2*sigma**2))


plotting_params = {'backend': 'wxAgg',
                   'font.family': 'serif',
                   'font.size': 22,
                   'lines.markersize' : 2,
                   'axes.labelsize': 22,
                   'legend.fontsize': 22,
                   'xtick.labelsize': 22,
                   'ytick.labelsize': 22,
                   'text.usetex': True}

plt.rcParams.update(plotting_params)

bin_size = 5

Line1 = 1393.7550
Line2 = 1402.7700

n1 = 400
n2 = 1500

g1 = 0
g2 = 320

empty_array = np.zeros(shape=(len(DP),len(DP[nobs])))

amplitude = empty_array
shift = empty_array
width = empty_array

amplitude_err = empty_array
shift_err = empty_array
width_err = empty_array

diffg = empty_array

for nobs in range(len(DP)):
    fig = plt.figure(figsize=(16.0,22.0))
    ax1 = plt.subplot(121)
    ax2 = plt.subplot(122)

    ax1.plot([0,0],[-3.2e-12,0.5e-12],'--k',lw=0.5)
    ax2.plot([0,0],[-3.2e-12,0.5e-12],'--k',lw=0.5)
    
    
    date = str(D[nobs][0][3])[:10]
    
    rv = c.Wave2RV(DP[nobs][0][0],Line1,20.5)
    x, y = c.BinXY(rv,DP[nobs][0][1],bin_size)
    s1, s2 = c.RegionSelect(x, n1, n2)
    gg1, gg2 = c.RegionSelect(rv, g1, g2)
    g = rv[gg1:gg2]
    
    ticks = []
    times = []

    x1, y1 = c.BinXY(rv,DP[nobs][0][1],bin_size)

    for i in range(len(DP[nobs])):
        offset = i*1.2e-13
        x, y = c.BinXY(rv,DP[nobs][i][1],bin_size)

        ticks.append(np.median(y1[s1:s2]-y[s1:s2])-offset)
        times.append(str(DP[nobs][i][3])[11:])

        if i not in [0]:
            diffg = (DP[nobs][i][1]-DP[nobs][0][1])[gg1:gg2]
            xg = rv[gg1:gg2]
            popt,pcov = curve_fit(gauss,xg,diffg,p0=[5e-14,180,20])
            perr = np.sqrt(np.diag(pcov))
            amplitude_err[nobs][i] = perr[0]
            shift_err[nobs][i] = perr[1]
            width_err[nobs][i] = perr[2]
            ax1.plot(x,gauss(x,*popt)-offset,'-k')
            amplitude[nobs][i] = popt[0]
            shift[nobs][i] = popt[1]
            width[nobs][i] = popt[2]
            
            
        ax1.fill_between(x,y-y1-offset,np.median(y1[s1:s2]-y[s1:s2])*np.ones(len(x))-offset,step='pre',color=cool[i],alpha=0.5)
        ax1.set_xlabel(r'Radial Velocity [km/s]')
        ax1.set_xlim(-400,800)
        ax1.set_ylim(-1.35e-12,6.0e-14)

    
    rv = c.Wave2RV(DP[nobs][0][0],Line2,20.5)
    x, y = c.BinXY(rv,DP[nobs][0][1],bin_size)
    s1, s2 = c.RegionSelect(x, n1, n2)
    gg1, gg2 = c.RegionSelect(rv, g1, g2)
    g = rv[gg1:gg2]
    
    ticks = []
    times = []

    x1, y1 = c.BinXY(rv,DP[nobs][0][1],bin_size)

    for i in range(len(DP[nobs])):
        offset = i*1.2e-13
        x, y = c.BinXY(rv,DP[nobs][i][1],bin_size)

        ticks.append(np.median(y1[s1:s2]-y[s1:s2])-offset)
        times.append(str(DP[nobs][i][3])[11:])

        if i not in [0]:
            diffg = (DP[nobs][i][1]-DP[nobs][0][1])[gg1:gg2]
            xg = rv[gg1:gg2]
            popt,pcov = curve_fit(gauss,xg,diffg,p0=[5e-14,180,20])
            perr = np.sqrt(np.diag(pcov))
            amplitude_err[nobs][i] = perr[0]
            shift_err[nobs][i] = perr[1]
            width_err[nobs][i] = perr[2]
            ax2.plot(x,gauss(x,*popt)-offset,'-k')
            amplitude[nobs][i] = popt[0]
            shift[nobs][i] = popt[1]
            width[nobs][i] = popt[2]
            
            
        ax2.fill_between(x,y-y1-offset,np.median(y1[s1:s2]-y[s1:s2])*np.ones(len(x))-offset,step='pre',color=cool[i],alpha=0.5)
        ax2.set_xlabel(r'Radial Velocity [km/s]')
        ax2.set_xlim(-400,800)
        ax2.set_ylim(-1.35e-12,6.0e-14)
        ax1.title.set_text('SiIV @ '+str(Line1)+' \AA')
        ax2.title.set_text('SiIV @ '+str(Line2)+' \AA')
        fig.tight_layout()
        plt.savefig(home+'/plots/'+date+'_exocomets.pdf', bbox_inches='tight', pad_inches=0.1,dpi=300)

# %%
from datetime import timedelta
from scipy.stats import linregress


minutes = empty_array
print(minutes)

fig = plt.figure(figsize=(16.0,22.0))

plotting_params = {'backend': 'wxAgg',
                   'font.family': 'serif',
                   'font.size': 22,
                   'lines.markersize' : 2,
                   'axes.labelsize': 22,
                   'legend.fontsize': 22,
                   'xtick.labelsize': 22,
                   'ytick.labelsize': 22,
                   'text.usetex': True}

plt.rcParams.update(plotting_params)

ax1 = plt.subplot(421)
ax2 = plt.subplot(423)
ax3 = plt.subplot(425)
ax4 = plt.subplot(422)
ax5 = plt.subplot(424)
ax6 = plt.subplot(426)

for nobs in range(len(DP)):
    
    for i in range(len(DP[nobs])):
        times = str(DP[nobs][i][3])[11:]
        delta = timedelta(hours=int(times.split(':')[0]), minutes=int(times.split(':')[1]), seconds=int(times.split(':')[2]))
        minutes[nobs][i] = delta.total_seconds()/60


    minutes[nobs] = minutes[nobs]-minutes[nobs][0]




    if nobs == 0:
        print(minutes[nobs],amplitude[nobs])
        res1 = linregress(minutes[nobs], amplitude[nobs])
        #ax1.fill_between(minutes[nobs],(res1.slope+res1.stderr)*minutes[nobs]+res1.intercept+res1.intercept_stderr,(res1.slope-res1.stderr)*minutes[nobs]+res1.intercept-res1.intercept_stderr,color="black",alpha=0.1)
        #ax1.errorbar(minutes[nobs],amplitude[nobs],yerr=amplitude_err[nobs],capsize=5,ls="None",color="black")
        ax1.scatter(minutes[nobs],amplitude[nobs],s=80,zorder=2,color="black")
        #ax1.scatter(minutes[nobs],amplitude[nobs],s=50,zorder=2,label="Absorption depth")
        #ax1.plot(minutes[nobs],res1.slope*minutes[nobs]+res1.intercept,color="black")
        plt.ylabel(r'Flux [erg/s/cm$^2$/\AA]')
        #plt.ylim(0.2e-13,1.0e-13)
        print('\n\nAmplitude:\t p_value =',round(res1.pvalue,3))
        with open(home+'/data/variations_'+date+'.txt', 'w') as output:
            output.write('Amplitude:\t p_value = '+str(round(res1.pvalue,3))+'\n')


    res2 = linregress(minutes[nobs], shift[nobs])
    plt.fill_between(minutes[nobs],(res2.slope+res2.stderr)*minutes[nobs]+res2.intercept+res2.intercept_stderr,(res2.slope-res2.stderr)*minutes[nobs]+res2.intercept-res2.intercept_stderr,color="black",alpha=0.1)
    plt.errorbar(minutes[nobs],shift[nobs],yerr=shift_err[nobs],capsize=5,ls="None",color="black")
    plt.scatter(minutes[nobs],shift[nobs],zorder=2,s=80,color="black")
    plt.scatter(minutes[nobs],shift[nobs],zorder=2,s=50,label="Shift")
    plt.plot(minutes[nobs],res2.slope*minutes[nobs]+res2.intercept,color="black")
    plt.ylabel(r'RV [km/s]')
    #plt.ylim(150,220)
    print('Shift:\t\t p_value =',round(res2.pvalue,3))
    with open(home+'/data/variations_'+date+'.txt', 'a') as output:
        output.write('Shift:\t p_value = '+str(round(res2.pvalue,3))+'\n')

    
    res3 = linregress(minutes[nobs], width[nobs])
    plt.fill_between(minutes[nobs],(res3.slope+res3.stderr)*minutes[nobs]+res3.intercept+res3.intercept_stderr,(res3.slope-res3.stderr)*minutes[nobs]+res3.intercept-res3.intercept_stderr,color="black",alpha=0.1)
    plt.errorbar(minutes[nobs],width[nobs],yerr=width_err[nobs],capsize=5,ls="None",color="black")
    plt.scatter(minutes[nobs],width[nobs],zorder=2,s=80,color="black")
    plt.scatter(minutes[nobs],width[nobs],zorder=2,s=50,label="Shift")
    plt.plot(minutes[nobs],res3.slope*minutes[nobs]+res3.intercept,color="black")
    #plt.ylim(0,80)
    plt.xlabel(r'Minutes [s]')
    plt.ylabel(r'RV [km/s]')
    print('Width:\t\t p_value =',round(res3.pvalue,3))
    with open(home+'/data/variations_'+date+'.txt', 'a') as output:
        output.write('Width:\t p_value = '+str(round(res3.pvalue,3))+'\n\n')

    #minutes = np.delete(minutes, 6)

    
    res4 = linregress(minutes[nobs], amplitude[nobs])
    plt.fill_between(minutes[nobs],(res4.slope+res4.stderr)*minutes[nobs]+res4.intercept+res4.intercept_stderr,(res4.slope-res4.stderr)*minutes[nobs]+res4.intercept-res4.intercept_stderr,color="black",alpha=0.1)
    plt.errorbar(minutes[nobs],amplitude[nobs],yerr=amplitude_err[nobs],capsize=5,ls="None",color="black")
    plt.scatter(minutes[nobs],amplitude[nobs],s=80,zorder=2,color="black")
    plt.scatter(minutes[nobs],amplitude[nobs],s=50,zorder=2,label="Absorption depth")
    plt.plot(minutes[nobs],res4.slope*minutes[nobs]+res4.intercept,color="black")
    #plt.ylim(0.2e-13,1.0e-13)
    ax4.set(yticklabels=[]) 
    ax4.set(ylabel=None)   
    print('\nAmplitude:\t p_value =',round(res4.pvalue,3))
    with open(home+'/data/variations_'+date+'.txt', 'a') as output:
        output.write('Amplitude:\t p_value = '+str(round(res4.pvalue,3))+'\n')

    
    res5 = linregress(minutes[nobs], shift[nobs])
    plt.fill_between(minutes[nobs],(res5.slope+res5.stderr)*minutes[nobs]+res5.intercept+res5.intercept_stderr,(res5.slope-res5.stderr)*minutes[nobs]+res5.intercept-res5.intercept_stderr,color="black",alpha=0.1)
    plt.errorbar(minutes[nobs],shift[nobs],yerr=shift_err[nobs],capsize=5,ls="None",color="black")
    plt.scatter(minutes[nobs],shift[nobs],zorder=2,s=80,color="black")
    plt.scatter(minutes[nobs],shift[nobs],zorder=2,s=50,label="Shift")
    plt.plot(minutes[nobs],res5.slope*minutes[nobs]+res5.intercept,color="black")
    #plt.ylim(150,220)
    ax5.set(yticklabels=[]) 
    ax5.set(ylabel=None)   
    print('Shift:\t\t p_value =',round(res5.pvalue,3))
    with open(home+'/data/variations_'+date+'.txt', 'a') as output:
        output.write('Shift:\t p_value = '+str(round(res5.pvalue,3))+'\n')

    
    res6 = linregress(minutes[nobs], width[nobs])
    plt.fill_between(minutes[nobs],(res6.slope+res6.stderr)*minutes[nobs]+res6.intercept+res6.intercept_stderr,(res6.slope-res6.stderr)*minutes[nobs]+res6.intercept-res6.intercept_stderr,color="black",alpha=0.1)
    plt.errorbar(minutes[nobs],width[nobs],yerr=width_err[nobs],capsize=5,ls="None",color="black")
    plt.scatter(minutes[nobs],width[nobs],zorder=2,s=80,color="black")
    plt.scatter(minutes[nobs],width[nobs],zorder=2,s=50,label="Shift")
    plt.plot(minutes[nobs],res6.slope*minutes[nobs]+res6.intercept,color="black")
    #plt.ylim(0,80)
    plt.xlabel(r'Minutes [s]')
    ax6.set(yticklabels=[]) 
    ax6.set(ylabel=None)   
    print('Width:\t\t p_value =',round(res6.pvalue,3))
    with open(home+'/data/variations_'+date+'.txt', 'a') as output:
        output.write('Width:\t p_value = '+str(round(res6.pvalue,3)))

    ax1.title.set_text('SiIV @ '+str(Line1)+' \AA')
    ax4.title.set_text('SiIV @ '+str(Line2)+' \AA')
    fig.tight_layout()
    plt.savefig(home+'/plots/'+date+'_gaussian_parameters.pdf', bbox_inches='tight', pad_inches=0.1,dpi=300)
# Out:
# [[  0.          11.95        23.9         35.85        86.55
#   100.16666667 113.78333333 127.4        181.81666667 195.43333333
#   209.05      ]
#  [  0.          70.17250642  31.57752905  17.85439249  64.29020497
#    81.77473174  33.71082076  37.79388182  46.20226987  51.37238123
#    53.48123115]]
# [  0.          11.95        23.9         35.85        86.55
#  100.16666667 113.78333333 127.4        181.81666667 195.43333333
#  209.05      ] [  0.          11.95        23.9         35.85        86.55
#  100.16666667 113.78333333 127.4        181.81666667 195.43333333
#  209.05      ]
#
#
# Amplitude:	 p_value = 0.0
# Shift:		 p_value = 0.0
# Width:		 p_value = 0.0
#
# Amplitude:	 p_value = 0.0
# Shift:		 p_value = 0.0
# Width:		 p_value = 0.0
# Shift:		 p_value = 0.0
# Width:		 p_value = 0.0
#
# Amplitude:	 p_value = 0.0
# Shift:		 p_value = 0.0
# Width:		 p_value = 0.0
